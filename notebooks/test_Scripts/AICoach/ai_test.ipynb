# %%
from openai import OpenAI
import os
from IPython.display import Markdown, display
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key= os.getenv("test_ai_key")
)
model="mistralai/mistral-small-3.1-24b-instruct:free"

# %%
def get_response(client,selected_model,content):
    response = client.chat.completions.create(
        model = selected_model,
        messages=[
            {"role": "user", "content": content}
        ]
    )
    return response.choices[0].message.content

# %%
content = "Hello, Hows the average weather in winter in nyc?"
res = get_response(client,model,content)
display(Markdown(res))
# Out:
# Hello! In New York City, winter typically spans from December to February, with temperatures often dipping into the cold range. Here's an average breakdown:
#
# - **December**: Average high temperatures are around 43°F (6°C), and average low temperatures are around 30°F (-1°C). Snowfall can start in late December.
# - **January**: This is usually the coldest month, with average high temperatures around 39°F (4°C) and average low temperatures around 26°F (-3°C). Snowfall is common.
# - **February**: Average high temperatures are around 43°F (6°C), and average low temperatures are around 28°F (-2°C). Snowfall can still occur.
#
# It's also important to note that New York City can experience occasional cold snaps with temperatures dropping below 20°F (-6°C), and it can also have mild winter days where temperatures reach the 50s°F (around 10°C). Always check the forecast for the specific dates of your visit, as weather can vary.
#
# Additionally, winter in NYC can be quite windy, which can make it feel colder than the actual temperature. Be sure to dress in layers and wear a good winter coat, gloves, a hat, and a scarf.
